# %%
print("Hello World")
# Out:
# Hello World

# %%
#string functions

# %%
name = "Nitish"

# %%
name.lower()
# Out:
# 'nitish'

# %%
name=name.lower()

# %%
name.upper()
# Out:
# 'NITISH'

# %%
name.title()
# Out:
# 'Nitish'

# %%
name.swapcase()
# Out:
# 'NITISH'

# %%
name="Nitish"

# %%
name.swapcase()
# Out:
# 'nITISH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name="ok"
name1="123"
name2="ok123"

# %%
name.isalpha()
# Out:
# True

# %%
name1.isalpha()
# Out:
# False

# %%
name2.isalpha()
# Out:
# False

# %%
name.isdigit()
# Out:
# False

# %%
name.isdigit()
# Out:
# False

# %%
name1.isdigit()
# Out:
# True

# %%
name2.isdigit()
# Out:
# False

# %%
name.isalnum()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name.isalnum()
# Out:
# True

# %%
name = "pune"

# %%
print(name)
# Out:
# pune

# %%
name.startswith("p")
# Out:
# True

# %%
name=" pune "

# %%
print(name)
# Out:
#  pune

# %%
name.startswith("p")
# Out:
# False

# %%
name.endswith("p")
# Out:
# False

# %%
name.endswith(" pune ")
# Out:
# True

# %%
name.endswith("e")
# Out:
# False

# %%
name.endswith(" ")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'pune '

# %%
name.rstrip()
# Out:
# ' pune'

# %%
name.strip()
# Out:
# 'pune'

# %%
len(name)
# Out:
# 6

# %%
name.replace('u','oo')
# Out:
# ' poone '

# %%
name.replace('e','i')
# Out:
# ' puni '

# %%
#OPERATORS

# %%
#arithmetic

# %%
a=5
b=7

# %%
a+b
# Out:
# 12

# %%
a-b
# Out:
# -2

# %%
a*b
# Out:
# 35

# %%
a/b
# Out:
# 0.7142857142857143

# %%
a ** b #raise to
# Out:
# 78125

# %%
b // a #floor div
# Out:
# 1

# %%
b % a
# Out:
# 2

# %%
# assignment operator

# %%
z= 5

# %%
z
# Out:
# 5

# %%
z = z + 3

# %%
z
# Out:
# 17

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z + 3
z
# Out:
# 8

# %%
z +=3

# %%
z
# Out:
# 11

# %%
z -=3

# %%
z
# Out:
# 8

# %%
z *=3

# %%
z
# Out:
# 24

# %%
z /=3
z
# Out:
# 8.0

# %%
z %=3

# %%
z
# Out:
# 2.0

# %%
# comparison operator

# %%
a
# Out:
# 5

# %%
b
# Out:
# 7

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# Logcal Operator

# %%
a = True
b = True

# %%
a and b
# Out:
# True

# %%
a = True 
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# Identity operator ->is ,is not

# %%
a = 5

# %%
b = 5

# %%
a is b
# Out:
# True

# %%
a is  not b
# Out:
# False

# %%
id(a), id(b)
# Out:
# (140733121078312, 140733121078312)

# %%
a =[3,4]
b =[3,4]

# %%
id(a),id(b)
# Out:
# (1957604848576, 1957604846336)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)

# %%
a
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %%
# membership selection operator ->in

# %%
l = [4, 6, 19, 10]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
4 in l
# Out:
# True

# %%
2 not in l
# Out:
# True

# %%
## precedence and association

# %%
#BODMAS

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3 # right association
# Out:
# 256

# %%
2 ** 3//2
# Out:
# 4

# %%
#print function

# %%
name = "Geet"
marks = 76.78

# %%
print(name)
# Out:
# Geet

# %%
print(marks)
# Out:
# 76.78

# %% [markdown]
#  ## my name is geet and marks are 76.78

# %%
print("my name is",name, "and marks are",marks,)
# Out:
# my name is Geet and marks are 76.78

# %%
print("my name is %s and marks are %i" %(name,marks))
# Out:
# my name is Geet and marks are 76

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Geet and marks are 76.78

# %%
# dir and help

# %%
name
# Out:
# 'Geet'

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(name);

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
# ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(3)
# Out:
# '\x03'

# %%
chr(65)
# Out:
# 'A'

# %%
chr(35)
# Out:
# '#'

# %%
chr(45)
# Out:
# '-'

# %%
chr(40)
# Out:
# '('

# %%
# type casting

# %%
num1 = 34
num2 = 44.56
num3 ="ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num1)
# Out:
# '34'

# %%
str(num2)
# Out:
# '44.56'

# %%
int("25")
# Out:
# 25

# %%
# user input

# %%
a = input("Enter the number")
# Out:
# Enter the number 8

# %%
print("ok")
# Out:
# ok

# %%
# write a program for addition of two numbers using usre input

# %%
num1 = input("Enter the first number") 
num2 = input("Enter the second number")
# Out:
# Enter the first number 23
# Enter the second number 3

# %%
z = num1 + num2
print("Addition is ->",z)
# Out:
# Addition is -> 233

# %%
#read the time in second as user input and print the time in the format as hour:minutes:seconds

# %%
sec = input("Enter time in seconds")
# Out:
# Enter time in seconds 3500

# %%
sec = int(input("Enter time in seconds"))
hours = sec // 3600
minutes = (sec % 3600) // 60
seconds = sec % 60

print(f"{hours}:{minutes}:{seconds}")
# Out:
# Enter time in seconds 3600
# 1:0:0
