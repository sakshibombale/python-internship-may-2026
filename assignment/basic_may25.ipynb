# %%
print("Hello World")
# Out:
# Hello World

# %%
num= 24
num1 =3

# %%
print(num)
# Out:
# 24

# %%
print(num1)
# Out:
# 3

# %%
num2= num + num1
print(num2)
# Out:
# 27

# %%
name= "riya"

# %%
print(name)
# Out:
# riya

# %%
num = 28

# %%
num1 = 35.6

# %%
num2 = "riya"

# %%
type(num)
# Out:
# int

# %%
type(num1)
# Out:
# float

# %%
type(num2)
# Out:
# str

# %%
a, b, c = 2,3,"ok"

# %%
a
# Out:
# 2

# %%
b
# Out:
# 3

# %%
c
# Out:
# 'ok'

# %%
num = 2345**455

# %%
num
# Out:
# ...

# %%
num = 23e4

# %%
type(num)
# Out:
# float

# %%
sent = "I like Python Programming"

# %%
print(sent)
# Out:
# I like Python Programming

# %%
sent = 'I like "Python" programming'
print(sent)
# Out:
# I like "Python" programming

# %%
sent = "I like 'Python' programming"
print(sent)
# Out:
# I like 'Python' programming

# %%
a = 2
b = 3
z= a + b
print(z)
# Out:
# 5

# %%
a=2; b=4; c = a+b;
print(c)
# Out:
# 6

# %%
a, b, c = 2, 3,"ok"

# %%
a
# Out:
# 2

# %%
b
# Out:
# 3

# %%
c
# Out:
# 'ok'
