# %%
"""
1) Data -> Salary_Data.csv
2) cross validation -> 75.25 split (random state = 0)
3) built linear reg model
4) check accuracy & viz best fit line
Assumptions - > 1) Linearity , 2) No outliers 3) Heteroscasistic x
""";

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# check for linnearity

# %%
plt.title("sal vs exp")
plt.scatter(df['YearsExperience'], df['Salary']);
plt.xlabel("exp")
plt.ylabel("Sal")
# Out:
# Text(0, 0.5, 'Sal')

# %%
x = df[["YearsExperience"]]
y = df["Salary"]

# %%
print(x)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y;

# %%
# cross validation

# %%
# Split data into training and testing

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25,random_state=0)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((22, 1), (22,), (8, 1), (8,))

# %%
# build the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# val of m
lr.coef_
# Out:
# array([9379.71049195])

# %%
# val of c
lr.intercept_
# Out:
# np.float64(26986.691316737248)

# %%
# compare act and pred

# %%
y_pred = lr.predict(x_test)

# %%
pd.DataFrame({'actual' : y_test,
              'pred' : y_pred})
# Out:
#       actual           pred
# 2    37731.0   41056.257055
# 28  122391.0  123597.709384
# 13   57081.0   65443.504334
# 10   63218.0   63567.562235
# 26  116969.0  116093.940990
# 24  109431.0  108590.172597
# 27  112635.0  117031.912039
# 11   55794.0   64505.533285

# %%
# plot the best fit line on the previous scatter chart

# %%
plt.title("sal vs exp")
plt.scatter(df['YearsExperience'], df['Salary']);
plt.xlabel("exp")
plt.ylabel("Sal")
plt.plot(x, lr.predict(x), color = 'black', ls = '--');

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 3508.5455930660555

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9779208335417602

# %% [markdown]
# # polynomial reg

# %%
print(x)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
# create polynomial features

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 3)

# %%
x_poly  = poly.fit_transform(x)

# %%
x_poly
# Out:
# array([[1.000000e+00, 1.100000e+00, 1.210000e+00, 1.331000e+00],
#        [1.000000e+00, 1.300000e+00, 1.690000e+00, 2.197000e+00],
#        [1.000000e+00, 1.500000e+00, 2.250000e+00, 3.375000e+00],
#        [1.000000e+00, 2.000000e+00, 4.000000e+00, 8.000000e+00],
#        [1.000000e+00, 2.200000e+00, 4.840000e+00, 1.064800e+01],
#        [1.000000e+00, 2.900000e+00, 8.410000e+00, 2.438900e+01],
#        [1.000000e+00, 3.000000e+00, 9.000000e+00, 2.700000e+01],
#        [1.000000e+00, 3.200000e+00, 1.024000e+01, 3.276800e+01],
#        [1.000000e+00, 3.200000e+00, 1.024000e+01, 3.276800e+01],
#        [1.000000e+00, 3.700000e+00, 1.369000e+01, 5.065300e+01],
#        [1.000000e+00, 3.900000e+00, 1.521000e+01, 5.931900e+01],
#        [1.000000e+00, 4.000000e+00, 1.600000e+01, 6.400000e+01],
#        [1.000000e+00, 4.000000e+00, 1.600000e+01, 6.400000e+01],
#        [1.000000e+00, 4.100000e+00, 1.681000e+01, 6.892100e+01],
# ...

# %%
# cross val, linear reg model, r2_score

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split( x_poly, y, test_size=0.2, random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9048429887854866

# %%
plt.title("sal vs exp")
plt.xlabel("exp")
plt.ylabel("sal")
plt.scatter(df['YearsExperience'], df['Salary']);
plt.plot(x, lr.predict(x_poly), color = 'black', ls = '--');

# %%
# check for overfit

print("train:", lr.score(x_train, y_train))  # training acc
print("test:", lr.score(x_test, y_test)) # test acc
# Out:
# train: 0.9713086548187269
# test: 0.9048429887854866
