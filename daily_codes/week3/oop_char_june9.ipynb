# %%
"""  
create a class called student
create 2-3 objects having attributes name, age

create a method which will add a skill (eg.. python, ML, Java) to the student
where u can view the info of it later (i.e. skills learned by a student)
""";

# %%
class Student:

    def __init__ (self, name, age):
        self.name = name
        self.age = age
        self.skills = []

    def add_skill(self, skill):
        return self.skills.append(skill)

# %%
s1 = Student('avinash', 30)

# %%
s1.add_skill('java')

# %%
s1.skills
# Out:
# ['java']

# %%
s1.add_skill('python')

# %%
s1.skills
# Out:
# ['java', 'python']

# %% [markdown]
# # Inheritance

# %%
class Person:
    insti = "MITU"

    def __init__ (self, age, ht):
        self.age = age
        self.ht = ht

    def show(self):
        print(f"age -> {self.age}, height -> {self.ht}, institute -> {self.insti}")

# %%
class Ravi(Person):

    def __init__(self, age, ht, sal):
        super().__init__(age, ht)
        self.sal = sal

    def show_sal(self):
        print(f"salary is {self.sal}")

# %%
a = Ravi(25, 5.9, 57000)

# %%
a.show_sal()
# Out:
# salary is 57000

# %%
a.show()
# Out:
# age -> 25, height -> 5.9, institute -> MITU

# %% [markdown]
# # Polymorphism

# %%
class Animal:

    def speak(self):
        return "Sound of an animal"

# %%
class Dog(Animal):

    def speak(self):
        return "woof!!!"

class Cat(Animal):

    def speak(self):
        return "meow!!!" 
#%%

# %%
d = Dog()
c = Cat()

# %%
d.speak()
# Out:
# 'woof!!!'

# %%
c.speak()
# Out:
# 'meow!!!'

# %%
# simple menu driven with oop

# %%
# add items, view, exit (grocery list)

# %%
class Menuapp:

    def __init__ (self):
        self.itemlist = []

    def show_menu(self):

        print("Menu\n1.add items\n2. view items\n3. exit")

    def add_items(self):
        item = input("enter the item name:")
        self.itemlist.append(item)

    def view_items(self):
        return self.itemlist
    
    def run(self):

        while True:
            
            self.show_menu()

            ch = int(input("enter the choice"))

            if ch == 1:
                self.add_items()
            elif ch == 2:
                self.view_items()
            elif ch == 3:
                break
            else:
                return 'invalid choice'

# %%
atharv = Menuapp()

# %%
atharv.run()
# Out:
# Menu
# 1.add items
# 2. view items
# 3. exit
# enter the choice 1
# enter the item name: sakshi
# Menu
# 1.add items
# 2. view items
# 3. exit
# enter the choice 2
# Menu
# 1.add items
# 2. view items
# 3. exit
# enter the choice 3

# %%
atharv.itemlist
# Out:
# ['sakshi']

# %%
# encapsulation with getter and setter

# %%
class Person:

    def __init__ (self, age, name):

        self.__age = age
        self.__name = name

    # getter
    def get_name(self):
        return self.__name
    
    def get_age(self):
        return self.__age
    
    # setter
    def set_age(self, age):
        self.__age = age

# %%
p = Person(34, 'Arun')

# %%
p.get_age()
# Out:
# 34

# %%
p.set_age(50)

# %%
p.get_age()
# Out:
# 50

# %%
# dunder methods/ magic methods

# %%
dir(p)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'get_age',
#  'get_name',
#  'set_age']

# %%
print(p)
# Out:
# <__main__.Person object at 0x00000216B411C440>

# %%
# __str__

# %%
class Person:

    def __init__ (self, age, name):

        self.__age = age
        self.__name = name

    # getter
    def get_name(self):
        return self.__name
    
    def get_age(self):
        return self.__age
    
    # setter
    def set_age(self, age):
        self.__age = age
        

    def __str__(self):
        return f"age -> {self.__age}, name -> {self.__name}"

# %%
p = Person(34, 'Arun')

# %%
print(p)
# Out:
# age -> 34, name -> Arun

# %%
# create a menu driven app for banking simulation
# check balance, deposit money, withdraw money (u can add more things as u 
# see fit to make the app better)
