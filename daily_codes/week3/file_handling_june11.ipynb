# %%
"""
create a sample text file with some text in it
""";

# %%
# open the file

f = open("sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f = open("sample.txt", "r")
print(f.readable())
# Out:
# True

# %%
f.readable()
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\Hp'

# %%
f.readline()
# Out:
# 'Hello, this is a sample text file.\n'

# %%
f.readline()
# Out:
# 'I am learning file handling in Python.\n'

# %%
f.readline()
# Out:
# ''

# %%
f = open("sample.txt")

# %%
f.readline(10)
# Out:
# 'Hello, thi'

# %%
f.readline(5)
# Out:
# 'Hello'

# %%
f.readline()
# Out:
# ', this is a sample text file.\n'

# %%
# check readlines

# %%
f = open("sample.txt")

# %%
f.readlines()
# Out:
# ['Hello, this is a sample text file.\n',
#  'I am learning file handling in Python.\n']

# %%
f.readlines(10)
# Out:
# []

# %%
f.readlines(5)
# Out:
# []

# %%
f = open("sample.txt")

# %%
data = f.readlines()

# %%
data
# Out:
# ['Hello, this is a sample text file.\n',
#  'I am learning file handling in Python.\n']

# %%
data = f.readline()

# %%
data
# Out:
# ''

# %%
data = f.readlines()

# %%
for line in data:
    print(line)
# Out:
# Hello, this is a sample text file.
#
# I am learning file handling in Python.

# %%
# convert the data in upper case

# %%
f = open("sample.txt")

# %%
data = f.readlines()

# %%
data = line.upper()
data
# Out:
# 'I AM LEARNING FILE HANDLING IN PYTHON.\n'

# %%
data = line.upper()
data
# Out:
# 'I AM LEARNING FILE HANDLING IN PYTHON.\n'

# %%
f = open("sample.txt")

# %%
data = f.readlines()

# %%
for line in data:
    print(line.upper())
# Out:
# HELLO, THIS IS A SAMPLE TEXT FILE.
#
# I AM LEARNING FILE HANDLING IN PYTHON.

# %%
# read function

# %%
f = open("sample.txt")

# %%
f.read()
# Out:
# 'Hello, this is a sample text file.\nI am learning file handling in Python.\n'

# %%
f = open("sample.txt")

# %%
text = f.read()

# %%
text
# Out:
# 'Hello, this is a sample text file.\nI am learning file handling in Python.\n'

# %%
print(text)
# Out:
# Hello, this is a sample text file.
# I am learning file handling in Python.

# %%
text.split()
# Out:
# ['Hello,',
#  'this',
#  'is',
#  'a',
#  'sample',
#  'text',
#  'file.',
#  'I',
#  'am',
#  'learning',
#  'file',
#  'handling',
#  'in',
#  'Python.']

# %%
"""
create a text file with some text in marathi
""";

# %%
m = open("marathi.txt")

# %%
print(m.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 print(m.read())
#
# File ~\anaconda3\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 11: character maps to <undefined>

# %%
m = open("marathi.txt", "r", encoding="utf-8")
print(m.read())
m.close()
# Out:
# नमस्कार, ही एक नमुना मजकूर फाइल आहे.
# मी Python मध्ये फाइल हँडलिंग शिकत आहे.

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
# opening a file with context manager

# %%
with open('sample.txt') as f:
    data = f.read()

# %%
print(data)
# Out:
# Hello, this is a sample text file.
# I am learning file handling in Python.

# %%
# writing in a file

# %%
f = open('myfile.text', 'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines = ['frode took the ring.', 'he started his journey to mount doom .']

# %%
f.writelines(lines)

# %%
f.close()

# %%
# writelines -> takes the list of sentences form user and writes the in the file

# %%
# write()

# %%
sent = "frode took the ring.', 'he started his journey to mount doom ."

# %%
f = open('myfile.txt', 'w')
f.write(sent)
f.close()

# %%
# write into a myfile.text with context manager
# use write function and add 3 seperate lines

# %%
with open('myfile.txt', 'w') as f:
    f.write('this is first line\n')
    f.write('this is second line\n')
    f.write('this is third line\n')

# %%
# sample file copy operation

# %%
s = open('sample.txt', 'r')
f = open('myfile.txt', 'w')

# %%
contents = s.read()
f.write(contents)
f.close()

# %%
# append

# %%
s = open('sample.txt', 'a')

# %%
s.write('\ndone')
# Out:
# 5

# %%
s.close()

# %%
f.tell()
# Out:
# 35

# %%
f.seek(10)
# Out:
# 10

# %%
f.tell()
# Out:
# 10
